# %% [markdown]
# # FASE 1 · ANÁLISIS EXPLORATORIO DE DATOS (EDA)
#
# En esta primera fase se realiza una exploración inicial del conjunto de datos con el objetivo de comprender su estructura, evaluar su calidad y detectar posibles problemas antes de iniciar la fase de limpieza.
#
# A lo largo del análisis se revisan:
# - las dimensiones del dataset,
# - los tipos de variables,
# - la distribución general de las columnas,
# - la presencia de duplicados,
# - los valores nulos,
# - y los estadísticos descriptivos principales.
#
# Esta fase permite identificar qué transformaciones serán necesarias en la etapa posterior y establecer una base sólida para el análisis.

# %%
# Importación de librerías

import pandas as pd
import numpy as np

# Configuración para visualizar todas las columnas del DataFrame
pd.set_option('display.max_columns', None)

# %%
# Carga del dataset

df_hr = pd.read_csv("../files/raw/hr.csv")

# Visualizamos las primeras filas para comprobar que la carga se ha realizado correctamente

df_hr.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
# 2  37.0       Yes      Travel_Rarely       1373  Research & Development
# 3  33.0        No  Travel_Frequently       1392  Research & Development
# 4  27.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# Dimensiones del DataFrame

print(f"El DataFrame tiene {df_hr.shape[0]} filas y {df_hr.shape[1]} columnas.\n")
# Out:
# El DataFrame tiene 1474 filas y 35 columnas.

# %%
# Identificación de columnas por tipo de dato

df_categoricas = df_hr.select_dtypes(include='str')
df_numericas = df_hr.select_dtypes(exclude='str')

print(f"Variables Categóricas: {df_categoricas.columns.tolist()}")
print(f"Variables Numéricas: {df_numericas.columns.tolist()}")
# Out:
# Variables Categóricas: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# Variables Numéricas: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# ## Exploración general de las variables
#
# A continuación, se revisa cada columna para conocer su tipo de dato, porcentaje de valores nulos y número de valores únicos.
# En el caso de las variables categóricas, también se muestra una muestra de sus categorías para facilitar su interpretación.

# %%
# Revisión general por columna

print("ANÁLISIS POR COLUMNA\n")

for columna in df_hr.columns:
    print("Columna: ", columna)
    print("Tipo de dato: ", df_hr[columna].dtype)
    print(f"Porcentaje de nulos: {round(df_hr[columna].isnull().mean() * 100, 2)}%")
    print("Valores únicos: ", df_hr[columna].unique())
    print("Número de valores únicos: ", df_hr[columna].nunique())
    print("----------------------\n")
# Out:
# ANÁLISIS POR COLUMNA
#
# Columna:  Age
# Tipo de dato:  float64
# Porcentaje de nulos: 4.95%
# Valores únicos:  [41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. nan 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60.]
# Número de valores únicos:  43
# ----------------------
#
# Columna:  Attrition
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# Número de valores únicos:  2
# ----------------------
#
# Columna:  BusinessTravel
# Tipo de dato:  str
# Porcentaje de nulos: 7.94%
# Valores únicos:  <StringArray>
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel', nan]
# Length: 4, dtype: str
# Número de valores únicos:  3
# ----------------------
#
# Columna:  DailyRate
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
# ...

# %%
# Revisión de variables constantes o con una única categoría

columnas_constantes = ["Over18", "EmployeeCount", "StandardHours"]

for col in columnas_constantes:
    print(f"{col}: {df_hr[col].unique()}")
# Out:
# Over18: <StringArray>
# ['Y']
# Length: 1, dtype: str
# EmployeeCount: [1]
# StandardHours: [80. nan]

# %%
# Identificación de filas duplicadas

print(f"El DataFrame contiene {df_hr.duplicated().sum()} filas duplicadas.")
df_hr[df_hr.duplicated()]
# Out:
# El DataFrame contiene 4 filas duplicadas.
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 1470  28.0        No  Travel_Rarely        866                   Sales
# 1471  53.0        No  Travel_Rarely       1084  Research & Development
# 1472  24.0       Yes  Travel_Rarely        240         Human Resources
# 1473  45.0        No  Travel_Rarely       1339  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 1470                 5          3          Medical              1
# 1471                13          2          Medical              1
# 1472                22          1  Human Resources              1
# 1473                 7          3    Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1470            1469                        4    Male          84
# 1471             250                        4  Female          57
# ...

# %%
# Estadísticos descriptivos de las variables numéricas

df_hr.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1401.0     36.944325     9.105009    18.0    30.00
# DailyRate                 1474.0    802.702171   403.539530   102.0   465.00
# DistanceFromHome          1474.0      9.199457     8.104266     1.0     2.00
# Education                 1474.0      2.911126     1.024267     1.0     2.00
# EmployeeCount             1474.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1474.0   1024.471506   602.421193     1.0   488.75
# EnvironmentSatisfaction   1474.0      2.723881     1.093280     1.0     2.00
# HourlyRate                1474.0     65.887381    20.310444    30.0    48.00
# JobInvolvement            1474.0      2.729986     0.712861     1.0     2.00
# JobLevel                  1474.0      2.063772     1.106055     1.0     1.00
# JobSatisfaction           1445.0      2.728720     1.106409     1.0     2.00
# ...

# %%
# Estadísticos descriptivos de las variables categóricas

df_hr.describe(include="str").T
# Out:
#                count unique                     top  freq
# Attrition       1474      2                      No  1236
# BusinessTravel  1357      3           Travel_Rarely   955
# Department      1445      3  Research & Development   941
# EducationField  1416      6           Life Sciences   582
# Gender          1474      2                    Male   885
# JobRole         1474      9        sALES eXECUTIVE    327
# MaritalStatus   1342      4                 Married   604
# Over18          1474      1                       Y  1474
# OverTime        1430      2                      No  1025

# %%
# Resumen de valores nulos por columna

porcentaje_nulos = round((df_hr.isnull().sum() / df_hr.shape[0]) * 100, 2)
porcentaje_nulos[porcentaje_nulos > 0].sort_values(ascending=False)
# Out:
# StandardHours            11.13
# YearsWithCurrManager     10.04
# MaritalStatus             8.96
# BusinessTravel            7.94
# TrainingTimesLastYear     5.97
# Age                       4.95
# EducationField            3.93
# OverTime                  2.99
# Department                1.97
# JobSatisfaction           1.97
# MonthlyIncome             0.95
# dtype: float64

# %%
# Listado de Job Roles por Department
df_hr[['Department', 'JobRole']].drop_duplicates().sort_values(by='Department')
# Out:
#                  Department                      JobRole
# 79          Human Resources             hUMAN rESOURCES
# 105         Human Resources                     mANAGER
# 1    Research & Development          rESEARCH sCIENTIST
# 2    Research & Development       lABORATORY tECHNICIAN
# 8    Research & Development      mANUFACTURING dIRECTOR
# 9    Research & Development   hEALTHCARE rEPRESENTATIVE
# 22   Research & Development           rESEARCH dIRECTOR
# 25   Research & Development                     mANAGER
# 0                     Sales             sALES eXECUTIVE
# 18                    Sales                     mANAGER
# 21                    Sales        sALES rEPRESENTATIVE
# 7                       NaN       lABORATORY tECHNICIAN
# 46                      NaN             sALES eXECUTIVE
# 65                      NaN                     mANAGER
# 222                     NaN           rESEARCH dIRECTOR
# 410                     NaN      mANUFACTURING dIRECTOR
# ...

# %% [markdown]
# Este análisis exploratorio permite revisar la correspondencia entre departamento y puesto.
# A partir de este resultado se detecta que algunos valores de JobRole, como "Manager", aparecen en varios departamentos distintos. Esto puede generar ambigüedad en la interpretación de la categoría, ya que el nombre del puesto no recoge suficiente contexto.
# Por ello, en la fase de transformación se planteará enriquecer esta variable incorporando el departamento en aquellos casos necesarios para mejorar su claridad y trazabilidad analítica.

# %% [markdown]
# ### Conclusión
#
# El análisis exploratorio ha permitido identificar las principales características del dataset, así como detectar posibles problemas de calidad de los datos.
#
# Se han observado valores nulos en determinadas variables, inconsistencias en formatos y la necesidad de transformar algunas columnas para facilitar su análisis. Además, se han identificado variables potencialmente relevantes para el estudio del attrition, como el nivel del puesto, el salario, el equilibrio vida-trabajo y la carga laboral.
#
# Este análisis inicial sienta las bases para la siguiente fase, en la que se realizará la limpieza y transformación del dataset con el fin de preparar los datos para un análisis más profundo.
